# %% [markdown]
# <a href="https://colab.research.google.com/github/guttulaswathi/ml/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 3
# 1. Basic Line Plot
# Plot a simple line graph of 𝑦 = 𝑥^2 for 𝑥 values ranging from -10 to 10.
# Label the x-axis as "X Values" and the y-axis as "Squared Values."
# Add a title to the graph.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 100) #Generates 100 random values from -10 to 10
y = x**2
plt.plot(x, y)
plt.xlabel('X Values')
plt.ylabel('Squared Values')
plt.title('Basic Line Plot for y=x^2')  #Generates heading for the Graph
plt.show() #For displaying

# %% [markdown]
# 2.Bar Plot
# Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi', 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].
# Add labels to the x-axis and y-axis and give the chart a title.

# %%
import matplotlib.pyplot as plt
students = ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
marks = [85, 90, 78, 92, 88]
plt.bar(students, marks)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Marks scored by 5 Students')
plt.show()

# %% [markdown]
# 3.Scatter Plot
# Generate two lists of 20 random integers each (for x and y coordinates).
# Create a scatter plot with these values, and customize it by adding color, size, and labels to the

# %%
import matplotlib.pyplot as plt
import random
x = [random.randint(1, 100) for _ in range(20)]
y = [random.randint(1, 100) for _ in range(20)]
colors = ['blue', 'green', 'red', 'blue', 'green', 'red', 'blue', 'green', 'red', 'blue', 'green', 'red', 'blue', 'green', 'red', 'blue', 'green', 'red', 'blue', 'green']
sizes = [random.randint(10, 100) for _ in range(20)]
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Customizations')
plt.show()

# %% [markdown]
# 4. Histogram
# Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram.
# Customize the number of bins and add a grid to the plot.

# %%
import  matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(100)
plt.hist(data, bins=10, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Values')
plt.grid(True)  #Adds rows and columns as grid on the whole graph
plt.show()

# %% [markdown]
# 5. Pie Chart
# Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E'] with values [20, 30, 25, 15, 10].
# Display the percentage values on the chart and use a color palette for differentiation

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C', 'D', 'E']
values = [20, 30, 25, 15, 10]
colors = ['blue', 'green', 'red', 'orange', 'purple']
plt.pie(values, labels=categories, colors=colors, autopct='%1.1f%%')
plt.title('Percentage Distribution of Categories')
plt.show()

# %% [markdown]
# 6. Box Plot (Seaborn)
# Create a box plot to visualize the distribution of the marks scored by students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].
# Highlight the median and any outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
sns.boxplot(data=marks, color='lightblue', width=0.5)
plt.ylabel('Marks')
plt.title('Box Plot of Marks')
plt.show()

# %% [markdown]
# 7. Heatmap (Seaborn)
# Create a 5x5 matrix with random integers between 1 and 10 using np.random.randint() and visualize it as a heatmap using Seaborn.
# Add a color bar and annotate the heatmap with the

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
matrix = np.random.randint(1, 11, size=(5, 5))
sns.heatmap(matrix,annot=True, fmt='d')
plt.title('Heatmap of Matrix')
plt.show()

# %% [markdown]
# 8.Comparison of Matplotlib and Seaborn
# Generate a pair of plots (bar charts or line plots) using the same data in both Matplotlib and Seaborn.
# Highlight the differences in the code, syntax, and aesthetics of the two libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for the plots
x = np.linspace(0, 10, 100)
y1 = np.sin(x)

# Line plot using Matplotlib
plt.figure(figsize=(4,4))
plt.plot(x, y1)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot using Matplotlib')
plt.show()

# Line plot using Seaborn
plt.figure(figsize=(4,4))
sns.lineplot(x=x, y=y1, color='red')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot using Seaborn')
plt.show()

# %% [markdown]
# 9. Pair Plot (Seaborn)
# Manually create a small dataset with columns such as 'Age', 'Height', 'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = {
    'Age': [23, 25, 30, 22, 28, 35, 40, 21, 24, 33],
    'Height': [175, 160, 180, 165, 170, 178, 185, 162, 168, 174],
    'Weight': [70, 60, 80, 55, 65, 75, 85, 58, 68, 78]
}
df = pd.DataFrame(data)
sns.pairplot(df)

# %% [markdown]
# 10. Save and Style Plots
# Plot any graph of your choice and save it in both .png and .pdf formats.
# Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain how the style impacts the visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, label='sin(x)',color='red')
plt.plot(x, y2, label='cos(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine Functions')
plt.legend()
plt.savefig('plot.png')
plt.savefig('plot.pdf')
plt.show()
